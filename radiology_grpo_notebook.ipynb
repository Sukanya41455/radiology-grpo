# %%
# !git clone https://github.com/Sukanya41455/radiology-grpo.git
# Out:
# Cloning into 'radiology-grpo'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 52 (delta 20), reused 12 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (52/52), 23.04 KiB | 7.68 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
# %cd radiology-grpo
# Out:
# /content/radiology-grpo

# %%
# !pip install -r requirements.txt

# %% [markdown]
# **With toy example**

# %%
# !python scripts/create_toy_data.py
# Out:
# Wrote 200 toy samples to data/toy_reports.jsonl

# %%
# !python -m src.train_supervised
# Out:
# tokenizer_config.json: 100% 26.0/26.0 [00:00<00:00, 197kB/s]
# config.json: 100% 762/762 [00:00<00:00, 7.28MB/s]
# vocab.json: 100% 1.04M/1.04M [00:00<00:00, 5.37MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 6.64MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 6.91MB/s]
# 2025-11-29 07:46:06.918259: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764402366.935548     380 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764402366.940409     380 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python -m src.train_grpo
# Out:
# 2025-11-29 07:47:08.542333: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764402428.558447     715 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764402428.563526     715 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764402428.578041     715 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# Plugging kaggle dataset

# %%
# !export KAGGLE_API_TOKEN=....

# %%
import kagglehub

path = kagglehub.dataset_download("raddar/chest-xrays-indiana-university")
print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university

# %%
#path = /kaggle/input/chest-xrays-indiana-university

# %%
# !python scripts/convert_iu_to_jsonl_with_images.py
# Out:
# Loading CSVs...
# Reports columns: ['uid', 'MeSH', 'Problems', 'image', 'indication', 'comparison', 'findings', 'impression']
# Projections columns: ['uid', 'filename', 'projection']
# Merged rows: 3689
# Wrote 3199 samples to data/iu_reports_with_images.jsonl

# %%
# !python scripts/test_image_dataset.py
# Out:
# Dataset size: 3199
# Prompt: FINDINGS:
# Reference: The cardiac silhouette and mediastinum size are within normal limits. There is no pulmonary edema. There is no focal consolidation. There are no XXXX of a pleural effusion. There is no evidence of pneumothorax. ...
# Image tensor shape: torch.Size([3, 224, 224])
# Figure(640x480)

# %%
# !python -m src.train_supervised
# Out:
# 2025-11-29 08:12:21.389231: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764403941.406869    7066 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764403941.412195    7066 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764403941.427620    7066 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python -m src.train_grpo
# Out:
# 2025-11-29 08:15:49.808029: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764404149.824670    7947 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764404149.829910    7947 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764404149.845561    7947 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python -m src.train_supervised_vision
# Out:
# 2025-11-29 09:50:06.648397: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764409806.680086   22070 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764409806.689486   22070 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764409806.712963   22070 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python -m src.eval_vision_model

# %% [markdown]
# GRPO integration

# %%
# !python -m src.train_grpo_vision
# Out:
# 2025-11-29 09:45:13.088775: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764409513.155342   20849 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764409513.184536   20849 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764409513.258776   20849 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
